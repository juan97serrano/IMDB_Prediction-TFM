# %%
import csv   
import pandas as pd
import numpy as np

# %%
data1 =  pd.read_csv('film_actors.csv',  sep='\t', engine='python', header= 0)
data2 =  pd.read_csv('film_actors_1.csv',  sep='\t', engine='python', header= 0)
data3 =  pd.read_csv('film_actors_2.csv',  sep='\t', engine='python', header= 0)
data4 =  pd.read_csv('film_actors_3.csv',  sep='\t', engine='python', header= 0)
data5 =  pd.read_csv('film_actors_4.csv',  sep='\t', engine='python', header= 0)
data6 =  pd.read_csv('film_actors_5.csv',  sep='\t', engine='python', header= 0)
data7 =  pd.read_csv('film_actors_6.csv',  sep='\t', engine='python', header= 0)
data8 =  pd.read_csv('film_actors_7.csv',  sep='\t', engine='c', header= 0)
data9 =  pd.read_csv('film_actors_8.csv',  sep='\t', engine='python', header= 0)
data10 =  pd.read_csv('film_actors_9.csv',  sep='\t', engine='python', header= 0)
data11 =  pd.read_csv('film_actors_likes_def.csv',  sep='\t', engine='python', header= 0)

data13 =  pd.read_csv('film_actors_likes_def_2.csv',  sep='\t', engine='python', header= 0)
data14 =  pd.read_csv('film_actors_likes_def_3.csv',  sep='\t', engine='python', header= 0)
data15 =  pd.read_csv('film_actors_likes_def_4.csv',  sep='\t', engine='python', header= 0)
data16 =  pd.read_csv('film_actors_likes_def_5.csv',  sep='\t', engine='python', header= 0)
data17 =  pd.read_csv('film_actors_likes_def_6.csv',  sep='\t', engine='python', header= 0)
data18 =  pd.read_csv('film_actors_likes_def_7.csv',  sep='\t', engine='python', header= 0)
data19 =  pd.read_csv('film_actors_likes_def_8.csv',  sep='\t', engine='python', header= 0)
data20 =  pd.read_csv('film_actors_likes_def_9.csv',  sep='\t', engine='python', header= 0)
data21 =  pd.read_csv('film_actors_likes_def_10.csv',  sep='\t', engine='python', header= 0)
data22 =  pd.read_csv('film_actors_likes_def_11.csv',  sep='\t', engine='python', header= 0)
data23 =  pd.read_csv('film_actors_likes_def_12.csv',  sep='\t', engine='python', header= 0)
data24 =  pd.read_csv('film_actors_likes_def_13.csv',  sep='\t', engine='python', header= 0)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-2-fcda4a478ac6> in <module>()
# ----> 1 data1 =  pd.read_csv('film_actors.csv',  sep='\t', engine='python', header= 0)
#       2 data2 =  pd.read_csv('film_actors_1.csv',  sep='\t', engine='python', header= 0)
#       3 data3 =  pd.read_csv('film_actors_2.csv',  sep='\t', engine='python', header= 0)
#       4 data4 =  pd.read_csv('film_actors_3.csv',  sep='\t', engine='python', header= 0)
#       5 data5 =  pd.read_csv('film_actors_4.csv',  sep='\t', engine='python', header= 0)
#
# ...

# %%
data8=data8.dropna()

# %%
data = pd.concat([data1,data2,data3,data4,data5,data6,data7,data8,data9,data10,data11,data13,data14,data15,data16,data17,\
                  data18,data19,data20,data21,data22,data23,data24])

# %%
data.reset_index(inplace = True)

# %%
data = data.drop(['index'],axis = 1)

# %%
data = data.drop(['ACTOR1_FACEBOOK_LIKES', 'ACTOR1_INSTAGRAM_LIKES','ACTOR1_TWITTER_LIKES','ACTOR2_FACEBOOK_LIKES','ACTOR2_INSTAGRAM_LIKES','ACTOR2_TWITTER_LIKES','ACTOR3_FACEBOOK_LIKES','ACTOR3_INSTAGRAM_LIKES','ACTOR3_TWITTER_LIKES'], axis=1)

# %%
data= data.drop_duplicates()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-81db37885431> in <module>()
# ----> 1 data= data.drop_duplicates()
#
# NameError: name 'data' is not defined

# %%
data.to_csv('FINAL_IMBD_ACTORS.csv')

# %% [markdown]
# CONCATENAR CON LOS DATOS QUE YA TENEMOS

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
data = pd.read_csv('/content/drive/My Drive/TFM/data/imdb_data.csv',header=0,decimal=',')

# %%
data.head()
# Out:
#    Unnamed: 0       CODE  ...      WRITERS_0 KEYWORDS_DESCRIPTION
# 0           0  tt4686108  ...        JaneDoe              azealia
# 1           1  tt0445033  ...        JaneDoe               friend
# 2           2  tt1167599  ...  MichaelHerbig               viking
# 3           3  tt4823434  ...   IssaLÃƒÂ³pez                  war
# 4           4  tt0220100  ...     MikeFiggis            hollywood
#
# [5 rows x 30 columns]

# %%
data2 = pd.read_csv('/content/drive/My Drive/TFM/data/FINAL_IMBD_ACTORS.csv',header=0,decimal=',')

# %%
data2.head()
# Out:
#    Unnamed: 0       CODE        ACTOR1_NAME      ACTOR2_NAME       ACTOR3_NAME
# 0           0  tt4928704    Isabelle Adjani  Corinne Masiero       LyÃ¨s Salem
# 1           1  tt0174224  Jean-Pierre Mocky    Sylvie BrÃ©al      Anne Deleuze
# 2           2  tt0106263       Fanny Ardant  Andrzej Seweryn    Bernard Le Coq
# 3           3  tt0384576    Denis Moschitto    Marie Zielcke      Hilmi SÃ¶zer
# 4           4  tt2905422    Celia Freijeiro    Cristina Pons  Sandra Collantes

# %%
data3 = pd.merge(data, data2, on='CODE')

# %%
data3.head()
# Out:
#    Unnamed: 0_x       CODE  ...         ACTOR2_NAME         ACTOR3_NAME
# 0             0  tt4686108  ...              Common  Lorraine Toussaint
# 1             1  tt0445033  ...           Rahul Dev          Raghuvaran
# 2             2  tt1167599  ...      Waldemar Kobus   GÃ¼nther Kaufmann
# 3             3  tt4823434  ...  Juan RamÃ³n LÃ³pez      Nery Arredondo
# 4             4  tt0220100  ...  Stellan SkarsgÃ¥rd         Salma Hayek
#
# [5 rows x 34 columns]

# %%
data3 = data3.loc[:, ~data3.columns.str.contains('^Unnamed')]
data3
# Out:
#              CODE  ...         ACTOR3_NAME
# 0       tt4686108  ...  Lorraine Toussaint
# 1       tt0445033  ...          Raghuvaran
# 2       tt1167599  ...   GÃ¼nther Kaufmann
# 3       tt4823434  ...      Nery Arredondo
# 4       tt0220100  ...         Salma Hayek
# ...           ...  ...                 ...
# 107176  tt0099876  ...  Miroslav MachÃ¡cek
# 107177  tt0052564  ...        Les Tremayne
# 107178  tt0051601  ...        Fernando Rey
# 107179  tt0151309  ...      Therese Kotara
# 107180  tt0022550  ...         Doris Lloyd
#
# [107181 rows x 32 columns]

# %%
data3.to_csv('COMPLETE_IMBD_DATA.csv')
