# %%
import csv   
import pandas as pd
import numpy as np

# %%
data =  pd.read_csv('../data/FINAL_IMBD_DATA.csv',  sep=',', engine='python', header= 0,index_col = 0)

# %%
no_oknw=data.replace('unknown',np.nan).dropna(axis = 0, how = 'any')

# %%
data = data[data['TITLE'] != 'unknown']
data
# Out:
#              CODE                                              TITLE  \
# 0       tt0000009                                         Miss Jerry
# 1       tt0000147                      The Corbett-Fitzsimmons Fight
# 2       tt0000335                              Soldiers of the Cross
# 3       tt0000502                                           Bohemios
# 4       tt0000574                        The Story of the Kelly Gang
# ...           ...                                                ...
# 542072  tt9916622     Rodolpho TeÃƒÂ³philo - O Legado de um Pioneiro
# 542073  tt9916680  De la ilusiÃƒÂ³n al desconcierto: cine colombi...
# 542074  tt9916706                                    Dankyavar Danka
# 542075  tt9916730                                             6 Gunn
# 542076  tt9916754               Chico Albuquerque - RevelaÃƒÂ§ÃƒÂµes
#
#                                               DESCRIPTION  DURATION  \
# 0       The adventures of a female reporter in the 1890s.     45min
# ...

# %%
data = data[data['DESCRIPTION'] != 'unknown']
data
# Out:
#              CODE                                              TITLE  \
# 0       tt0000009                                         Miss Jerry
# 1       tt0000147                      The Corbett-Fitzsimmons Fight
# 2       tt0000335                              Soldiers of the Cross
# 3       tt0000502                                           Bohemios
# 4       tt0000574                        The Story of the Kelly Gang
# ...           ...                                                ...
# 542072  tt9916622     Rodolpho TeÃƒÂ³philo - O Legado de um Pioneiro
# 542073  tt9916680  De la ilusiÃƒÂ³n al desconcierto: cine colombi...
# 542074  tt9916706                                    Dankyavar Danka
# 542075  tt9916730                                             6 Gunn
# 542076  tt9916754               Chico Albuquerque - RevelaÃƒÂ§ÃƒÂµes
#
#                                               DESCRIPTION  DURATION  \
# 0       The adventures of a female reporter in the 1890s.     45min
# ...

# %%
data = data[data['DURATION'] != 'unknown']
data
# Out:
#              CODE                                              TITLE  \
# 0       tt0000009                                         Miss Jerry
# 1       tt0000147                      The Corbett-Fitzsimmons Fight
# 3       tt0000502                                           Bohemios
# 4       tt0000574                        The Story of the Kelly Gang
# 9       tt0000679                     The Fairylogue and Radio-Plays
# ...           ...                                                ...
# 542070  tt9916538                                Kuambil Lagi Hatiku
# 542072  tt9916622     Rodolpho TeÃƒÂ³philo - O Legado de um Pioneiro
# 542073  tt9916680  De la ilusiÃƒÂ³n al desconcierto: cine colombi...
# 542075  tt9916730                                             6 Gunn
# 542076  tt9916754               Chico Albuquerque - RevelaÃƒÂ§ÃƒÂµes
#
#                                               DESCRIPTION  DURATION  \
# 0       The adventures of a female reporter in the 1890s.     45min
# ...

# %%
data = data[data['COLOR'] != 'unknown']
data
# Out:
#              CODE                                              TITLE  \
# 0       tt0000009                                         Miss Jerry
# 1       tt0000147                      The Corbett-Fitzsimmons Fight
# 3       tt0000502                                           Bohemios
# 4       tt0000574                        The Story of the Kelly Gang
# 9       tt0000679                     The Fairylogue and Radio-Plays
# ...           ...                                                ...
# 542070  tt9916538                                Kuambil Lagi Hatiku
# 542072  tt9916622     Rodolpho TeÃƒÂ³philo - O Legado de um Pioneiro
# 542073  tt9916680  De la ilusiÃƒÂ³n al desconcierto: cine colombi...
# 542075  tt9916730                                             6 Gunn
# 542076  tt9916754               Chico Albuquerque - RevelaÃƒÂ§ÃƒÂµes
#
#                                               DESCRIPTION  DURATION  \
# 0       The adventures of a female reporter in the 1890s.     45min
# ...

# %%
data = data[data['YEAR'] != 'unknown']
data
# Out:
#              CODE                                              TITLE  \
# 0       tt0000009                                         Miss Jerry
# 1       tt0000147                      The Corbett-Fitzsimmons Fight
# 3       tt0000502                                           Bohemios
# 4       tt0000574                        The Story of the Kelly Gang
# 9       tt0000679                     The Fairylogue and Radio-Plays
# ...           ...                                                ...
# 542070  tt9916538                                Kuambil Lagi Hatiku
# 542072  tt9916622     Rodolpho TeÃƒÂ³philo - O Legado de um Pioneiro
# 542073  tt9916680  De la ilusiÃƒÂ³n al desconcierto: cine colombi...
# 542075  tt9916730                                             6 Gunn
# 542076  tt9916754               Chico Albuquerque - RevelaÃƒÂ§ÃƒÂµes
#
#                                               DESCRIPTION  DURATION  \
# 0       The adventures of a female reporter in the 1890s.     45min
# ...

# %%
data = data[data['DIRECTOR'] != 'unknown']
data
# Out:
#              CODE                                              TITLE  \
# 0       tt0000009                                         Miss Jerry
# 1       tt0000147                      The Corbett-Fitzsimmons Fight
# 3       tt0000502                                           Bohemios
# 4       tt0000574                        The Story of the Kelly Gang
# 63      tt0001258                              Den hvide slavehandel
# ...           ...                                                ...
# 542064  tt9916186  Illenau - die Geschichte einer ehemaligen Heil...
# 542066  tt9916190                                          Safeguard
# 542070  tt9916538                                Kuambil Lagi Hatiku
# 542073  tt9916680  De la ilusiÃƒÂ³n al desconcierto: cine colombi...
# 542075  tt9916730                                             6 Gunn
#
#                                               DESCRIPTION  DURATION  \
# 0       The adventures of a female reporter in the 1890s.     45min
# ...

# %%
#data = data[data['BUDGET'] != 'unknown']
#data

# %%
#data = data[data['CWG'] != 'unknown']
#data

# %%
data = data[data['RATING'] != 'unknown']
data
# Out:
#              CODE                          TITLE  \
# 0       tt0000009                     Miss Jerry
# 1       tt0000147  The Corbett-Fitzsimmons Fight
# 3       tt0000502                       Bohemios
# 4       tt0000574    The Story of the Kelly Gang
# 63      tt0001258          Den hvide slavehandel
# ...           ...                            ...
# 542018  tt9914286          Sokagin Ãƒâ€¡ocuklari
# 542024  tt9914642                      Albatross
# 542025  tt9914644   9/11: Escape from the Towers
# 542036  tt9914942          La vida sin Sara Amat
# 542060  tt9916160                  DrÃƒÂ¸mmeland
#
#                                               DESCRIPTION  DURATION  \
# 0       The adventures of a female reporter in the 1890s.     45min
# 1       The first known feature film! A very unusual f...     20min
# 3                                         Add a Plot Ã‚Â»  1h 40min
# 4       True story of notorious Australian outlaw Ned ...  1h 10min
# ...

# %%
data = data[data['VOTES'] != 'unknown']
data
# Out:
#              CODE                          TITLE  \
# 0       tt0000009                     Miss Jerry
# 1       tt0000147  The Corbett-Fitzsimmons Fight
# 3       tt0000502                       Bohemios
# 4       tt0000574    The Story of the Kelly Gang
# 63      tt0001258          Den hvide slavehandel
# ...           ...                            ...
# 542018  tt9914286          Sokagin Ãƒâ€¡ocuklari
# 542024  tt9914642                      Albatross
# 542025  tt9914644   9/11: Escape from the Towers
# 542036  tt9914942          La vida sin Sara Amat
# 542060  tt9916160                  DrÃƒÂ¸mmeland
#
#                                               DESCRIPTION  DURATION  \
# 0       The adventures of a female reporter in the 1890s.     45min
# 1       The first known feature film! A very unusual f...     20min
# 3                                         Add a Plot Ã‚Â»  1h 40min
# 4       True story of notorious Australian outlaw Ned ...  1h 10min
# ...

# %%
#data = data[data['METASCORE RATING'] != 'unknown']
#data

# %%
data = data[data['GENRES'] != 'unknown']
data
# Out:
#              CODE                          TITLE  \
# 0       tt0000009                     Miss Jerry
# 1       tt0000147  The Corbett-Fitzsimmons Fight
# 4       tt0000574    The Story of the Kelly Gang
# 63      tt0001258          Den hvide slavehandel
# 65      tt0001285              The Life of Moses
# ...           ...                            ...
# 542018  tt9914286          Sokagin Ãƒâ€¡ocuklari
# 542024  tt9914642                      Albatross
# 542025  tt9914644   9/11: Escape from the Towers
# 542036  tt9914942          La vida sin Sara Amat
# 542060  tt9916160                  DrÃƒÂ¸mmeland
#
#                                               DESCRIPTION  DURATION  \
# 0       The adventures of a female reporter in the 1890s.     45min
# 1       The first known feature film! A very unusual f...     20min
# 4       True story of notorious Australian outlaw Ned ...  1h 10min
# 63      Anna, a young girl from a poor but honest hous...     45min
# ...

# %%
data = data[data['LANGUAGE'] != 'unknown']
data
# Out:
#              CODE                                           TITLE  \
# 112     tt0001790  Les misÃƒÂ©rables - Ãƒâ€°poque 1: Jean Valjean
# 119     tt0001911                         Sweet Nell of Old Drury
# 122     tt0001964                               Die VerrÃƒÂ¤terin
# 140     tt0002101                                       Cleopatra
# 150     tt0002153         DÃƒÂ¸dsspring til hest fra cirkuskuplen
# ...           ...                                             ...
# 542018  tt9914286                           Sokagin Ãƒâ€¡ocuklari
# 542024  tt9914642                                       Albatross
# 542025  tt9914644                    9/11: Escape from the Towers
# 542036  tt9914942                           La vida sin Sara Amat
# 542060  tt9916160                                   DrÃƒÂ¸mmeland
#
#                                               DESCRIPTION  DURATION  \
# 112     The story begins with Jean Valjean as a humble...        1h
# ...

# %%
data = data[data['COUNTRY'] != 'unknown']
data
# Out:
#              CODE                                           TITLE  \
# 112     tt0001790  Les misÃƒÂ©rables - Ãƒâ€°poque 1: Jean Valjean
# 119     tt0001911                         Sweet Nell of Old Drury
# 122     tt0001964                               Die VerrÃƒÂ¤terin
# 140     tt0002101                                       Cleopatra
# 150     tt0002153         DÃƒÂ¸dsspring til hest fra cirkuskuplen
# ...           ...                                             ...
# 542018  tt9914286                           Sokagin Ãƒâ€¡ocuklari
# 542024  tt9914642                                       Albatross
# 542025  tt9914644                    9/11: Escape from the Towers
# 542036  tt9914942                           La vida sin Sara Amat
# 542060  tt9916160                                   DrÃƒÂ¸mmeland
#
#                                               DESCRIPTION  DURATION  \
# 112     The story begins with Jean Valjean as a humble...        1h
# ...

# %%
#data = data[data['CONTENT RATING'] != 'unknown']
#data

# %%
data = data[data['KEYWORDS'] != 'unknown']
data
# Out:
#              CODE                                           TITLE  \
# 112     tt0001790  Les misÃƒÂ©rables - Ãƒâ€°poque 1: Jean Valjean
# 119     tt0001911                         Sweet Nell of Old Drury
# 140     tt0002101                                       Cleopatra
# 159     tt0002199                           Del pesebre a la cruz
# 184     tt0002423                                  Madame DuBarry
# ...           ...                                             ...
# 541775  tt9900180                                      Aavahayami
# 541795  tt9900782                                          Kaithi
# 541834  tt9903952                     BADMEN with a good behavior
# 541986  tt9910930                                     Jeg ser deg
# 541997  tt9913056                                    Swarm Season
#
#                                               DESCRIPTION  DURATION  \
# 112     The story begins with Jean Valjean as a humble...        1h
# ...

# %%
data = data[data['WRITERS'] != 'unknown']
data
# Out:
#              CODE                                           TITLE  \
# 112     tt0001790  Les misÃƒÂ©rables - Ãƒâ€°poque 1: Jean Valjean
# 119     tt0001911                         Sweet Nell of Old Drury
# 140     tt0002101                                       Cleopatra
# 159     tt0002199                           Del pesebre a la cruz
# 184     tt0002423                                  Madame DuBarry
# ...           ...                                             ...
# 541682  tt9894894                                          Kaviar
# 541707  tt9896916                          The Pilgrim's Progress
# 541795  tt9900782                                          Kaithi
# 541834  tt9903952                     BADMEN with a good behavior
# 541986  tt9910930                                     Jeg ser deg
#
#                                               DESCRIPTION  DURATION  \
# 112     The story begins with Jean Valjean as a humble...        1h
# ...

# %%
#data = data[data['OPENING WEEKEND'] != 'unknown']
#data

# %%
data.sort_values(by=['RATING'])
# Out:
#               CODE                              TITLE  \
# 6397     tt0012746                       Terror Trail
# 11181    tt0018486                        The Tigress
# 480311   tt6935730             Trilogy of Bloody Guts
# 367976   tt3132658              Elment az ÃƒÂ¶szÃƒÂ¶d
# 361001   tt2903902                   The Time Machine
# ...            ...                                ...
# 426979   tt5012400  Pieces of Lives, Pieces of Dreams
# 493645   tt7525642            A Medicine for the Mind
# 247278  tt10738796                    Time and motion
# 266548  tt11536510                  Couch Connections
# 412274        CODE                        ACTOR1_NAME
#
#                                               DESCRIPTION     DURATION  \
# 6397                                      Add a Plot Ã‚Â»           6h
# 11181   In Spain, a band of gypsies poach the deer in ...        54min
# 480311  Three short films by Russian low budget movie ...           1h
# ...

# %%
data = data[data['CODE'] != 'CODE']
data
# Out:
#              CODE                                           TITLE  \
# 112     tt0001790  Les misÃƒÂ©rables - Ãƒâ€°poque 1: Jean Valjean
# 119     tt0001911                         Sweet Nell of Old Drury
# 140     tt0002101                                       Cleopatra
# 159     tt0002199                           Del pesebre a la cruz
# 184     tt0002423                                  Madame DuBarry
# ...           ...                                             ...
# 541682  tt9894894                                          Kaviar
# 541707  tt9896916                          The Pilgrim's Progress
# 541795  tt9900782                                          Kaithi
# 541834  tt9903952                     BADMEN with a good behavior
# 541986  tt9910930                                     Jeg ser deg
#
#                                               DESCRIPTION  DURATION  \
# 112     The story begins with Jean Valjean as a humble...        1h
# ...

# %%
data.sort_values(by=['RATING'],ascending=False)
# Out:
#               CODE                              TITLE  \
# 266548  tt11536510                  Couch Connections
# 247278  tt10738796                    Time and motion
# 493645   tt7525642            A Medicine for the Mind
# 426979   tt5012400  Pieces of Lives, Pieces of Dreams
# 463191   tt6271662                              Hizam
# ...            ...                                ...
# 421024   tt4799698                Terra di i Turmenti
# 230769   tt1008023                     Proud American
# 6397     tt0012746                       Terror Trail
# 480311   tt6935730             Trilogy of Bloody Guts
# 11181    tt0018486                        The Tigress
#
#                                               DESCRIPTION  DURATION  \
# 266548  The world seems to separate people more than c...  1h 15min
# 247278  Trams, trains, subways, buses, ships and other...  1h 24min
# 493645  A new experimental drug for Alzheimer's, gifts...     15min
# ...

# %%
data
# Out:
#              CODE                                           TITLE  \
# 112     tt0001790  Les misÃƒÂ©rables - Ãƒâ€°poque 1: Jean Valjean
# 119     tt0001911                         Sweet Nell of Old Drury
# 140     tt0002101                                       Cleopatra
# 159     tt0002199                           Del pesebre a la cruz
# 184     tt0002423                                  Madame DuBarry
# ...           ...                                             ...
# 541682  tt9894894                                          Kaviar
# 541707  tt9896916                          The Pilgrim's Progress
# 541795  tt9900782                                          Kaithi
# 541834  tt9903952                     BADMEN with a good behavior
# 541986  tt9910930                                     Jeg ser deg
#
#                                               DESCRIPTION  DURATION  \
# 112     The story begins with Jean Valjean as a humble...        1h
# ...

# %%
data.reset_index(inplace = True)

# %%
data = data.drop(['index'],axis = 1)
data
# Out:
#              CODE                                           TITLE  \
# 0       tt0001790  Les misÃƒÂ©rables - Ãƒâ€°poque 1: Jean Valjean
# 1       tt0001911                         Sweet Nell of Old Drury
# 2       tt0002101                                       Cleopatra
# 3       tt0002199                           Del pesebre a la cruz
# 4       tt0002423                                  Madame DuBarry
# ...           ...                                             ...
# 113641  tt9894894                                          Kaviar
# 113642  tt9896916                          The Pilgrim's Progress
# 113643  tt9900782                                          Kaithi
# 113644  tt9903952                     BADMEN with a good behavior
# 113645  tt9910930                                     Jeg ser deg
#
#                                               DESCRIPTION  DURATION  \
# 0       The story begins with Jean Valjean as a humble...        1h
# ...

# %%
data.to_csv('../data/FILTERED_FINAL_IMBD_DATA.csv')
