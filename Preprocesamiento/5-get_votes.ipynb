# %% [markdown]
# Como en el proceso del preprocesamiento se modificaron el tipo de datos de la columna votes nos vemos obligados a volver a extraerlo del dataframe original

# %%
import pandas as pd
import numpy as np

# %%
datos_with_votes = pd.read_csv("/content/drive/My Drive/Máster KSchool/TFM/data/datos_antiguos/FILTERED_FINAL_IMBD_DATA.csv",sep=',',decimal=',',header=0)
datos = pd.read_csv("/content/drive/My Drive/Máster KSchool/TFM/data/imdb_data.csv",sep=',',decimal=',',header=0)
datos = datos.drop(columns=['Unnamed: 0', 'VOTES'])

# %%
datos_with_votes['VOTES']  = datos_with_votes['VOTES'].astype(str)
datos_with_votes['VOTES'] = datos_with_votes['VOTES'].apply(lambda x: x.replace('.',''))
datos_with_votes['VOTES']  = datos_with_votes['VOTES'].astype(int)

# %%
'''aux = datos_with_votes[datos_with_votes['CODE']=='tt3280916']
aux.describe()'''
# Out:
# "aux = datos_with_votes[datos_with_votes['CODE']=='tt3280916']\naux.describe()"

# %%
display(datos_with_votes[datos_with_votes['CODE']=='tt3280916'])
# Out:
#         Unnamed: 0       CODE  ...         WRITERS OPENING WEEKEND
# 100745      100745  tt3280916  ...  Chris Sparling         unknown
#
# [1 rows x 20 columns]

# %%
datos_with_votes = datos_with_votes[['CODE','VOTES']]

# %%
datos_with_votes.head()
# Out:
#         CODE  VOTES
# 0  tt0001790     21
# 1  tt0001911      7
# 2  tt0002101    430
# 3  tt0002199    453
# 4  tt0002423    723

# %%
datos = datos.merge(datos_with_votes,left_on='CODE', right_on='CODE')

# %%
datos[datos['CODE']=='tt3280916']
# Out:
#             CODE                 TITLE  ...      ACTOR_2  VOTES
# 11987  tt3280916  El Instituto Atticus  ...  JosefinaDoe   7911
#
# [1 rows x 32 columns]

# %%
datos.describe()
# Out:
#             DURATION           YEAR  CONTENT_RATING         VOTES
# count  107181.000000  107181.000000   107181.000000  1.071810e+05
# mean       95.319823    1986.954526        1.100867  6.654778e+03
# std        41.632378      26.076260        0.367972  4.426445e+04
# min         5.000000    1911.000000        1.000000  5.000000e+00
# 25%        84.000000    1968.000000        1.000000  4.100000e+01
# 50%        93.000000    1994.000000        1.000000  1.720000e+02
# 75%       104.000000    2009.000000        1.000000  8.960000e+02
# max     10062.000000    2020.000000        3.000000  2.188495e+06

# %%
datos[datos['CODE']=='tt3280916']
# Out:
#             CODE                 TITLE  ...      ACTOR_2  VOTES
# 11987  tt3280916  El Instituto Atticus  ...  JosefinaDoe   7911
#
# [1 rows x 32 columns]

# %%
datos.to_csv("imdb_data.csv")

# %%
aux = pd.read_csv("imdb_data.csv",sep=',')

# %%
aux[aux['CODE']=='tt3280916']
aux['VOTES']  = aux['VOTES'].astype(int)

# %%
aux.dtypes
# Out:
# Unnamed: 0                int64
# CODE                     object
# TITLE                    object
# DESCRIPTION              object
# DURATION                  int64
# COLOR                    object
# YEAR                      int64
# DIRECTOR                 object
# BUDGET                   object
# CWG                      object
# RATING                  float64
# METASCORE RATING         object
# GENRES                   object
# LANGUAGE                 object
# COUNTRY                  object
# CONTENT_RATING            int64
# KEYWORDS                 object
# WRITERS                  object
# OPENING WEEKEND          object
# GENRES_0                 object
# GENRES_1                 object
# GENRES_2                 object
# LANGUAGE_0               object
# KEYWORDS_0               object
# KEYWORDS_1               object
# KEYWORDS_2               object
# COUNTRY_0                object
# WRITERS_0                object
# KEYWORDS_DESCRIPTION     object
# ...

# %%
aux.describe()
# Out:
#           Unnamed: 0       DURATION  ...  CONTENT_RATING         VOTES
# count  107181.000000  107181.000000  ...   107181.000000  1.071810e+05
# mean    53590.000000      95.319823  ...        1.100867  6.654778e+03
# std     30940.633938      41.632378  ...        0.367972  4.426445e+04
# min         0.000000       5.000000  ...        1.000000  5.000000e+00
# 25%     26795.000000      84.000000  ...        1.000000  4.100000e+01
# 50%     53590.000000      93.000000  ...        1.000000  1.720000e+02
# 75%     80385.000000     104.000000  ...        1.000000  8.960000e+02
# max    107180.000000   10062.000000  ...        3.000000  2.188495e+06
#
# [8 rows x 6 columns]
