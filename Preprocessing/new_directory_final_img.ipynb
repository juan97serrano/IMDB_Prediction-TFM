# %% [markdown]
# # Libraries

# %%
import os
import pandas as pd
from shutil import copyfile
import tqdm

# %%
filtered_data = pd.read_csv("../data/FILTERED_FINAL_IMBD_DATA.csv", sep=',', engine='python', header=0,index_col=0)
code_list_filtered_data = list(filtered_data['CODE'])
import pandas as pd

string = '.png'

filtered_data['CODE'] = (pd.Series(code_list_filtered_data) + string).tolist()


filtered_ListImages = (pd.Series(code_list_filtered_data) + string).tolist()
len(filtered_ListImages)
# Out:
# 113646

# %%
filtered_data
# Out:
#                  CODE                                           TITLE  \
# 0       tt0001790.png  Les misÃƒÂ©rables - Ãƒâ€°poque 1: Jean Valjean
# 1       tt0001911.png                         Sweet Nell of Old Drury
# 2       tt0002101.png                                       Cleopatra
# 3       tt0002199.png                           Del pesebre a la cruz
# 4       tt0002423.png                                  Madame DuBarry
# 5       tt0002445.png                                      Quo Vadis?
# 6       tt0002514.png                              De svarta maskerna
# 7       tt0002588.png                      Zigomar contre Nick Carter
# 8       tt0002628.png                                      Der Andere
# 9       tt0002646.png                                        Atlantis
# 10      tt0002822.png                      What 80 Million Women Want
# 11      tt0002844.png        FantÃƒÂ³mas a la sombra de la guillotina
# ...

# %%
list_img_allow = os.listdir('../data/img')

# %%
dirImages = set(list_img_allow)
filtered_ListImages = set(filtered_ListImages)
films_in_comon = dirImages.intersection(filtered_ListImages)

# %%
films_in_comon =list(films_in_comon)

# %%
#for img in films_in_comon:
#    copyfile('../data/img/'+img, '../data/filtered_img/'+img)

# %%
films_in_comon = pd.DataFrame(films_in_comon,columns=['CODE'])

# %%
films_in_comon
# Out:
#                  CODE
# 0       tt4686108.png
# 1       tt0445033.png
# 2       tt1167599.png
# 3       tt4823434.png
# 4       tt0220100.png
# 5       tt0022339.png
# 6       tt1273191.png
# 7       tt0065230.png
# 8       tt0052702.png
# 9       tt0074109.png
# 10      tt0432131.png
# 11      tt0212872.png
# 12      tt0040464.png
# 13      tt0037711.png
# 14      tt0056591.png
# 15      tt0143848.png
# 16      tt0352864.png
# 17      tt0230997.png
# 18      tt0481598.png
# 19      tt0031929.png
# 20      tt0101452.png
# 21      tt0030631.png
# 22      tt0430321.png
# 23      tt0042278.png
# 24      tt0067521.png
# 25      tt0242795.png
# 26      tt0047327.png
# 27      tt0061460.png
# 28      tt0090631.png
# 29      tt0262614.png
# ...               ...
# 107151  tt0027483.png
# 107152  tt0073328.png
# 107153  tt0082408.png
# 107154  tt0020776.png
# 107155  tt0040161.png
# 107156  tt0354934.png
# 107157  tt0482613.png
# 107158  tt4008566.png
# 107159  tt0087896.png
# ...

# %%
filtered_df_with_img = films_in_comon.set_index('CODE').join(filtered_data.set_index('CODE'))

# %%
filtered_df_with_img.head(3)
# Out:
#                            TITLE  \
# CODE
# tt4686108.png  Love Beats Rhymes
# tt0445033.png               Mass
# tt1167599.png   Vicky el vikingo
#
#                                                      DESCRIPTION  DURATION  \
# CODE
# tt4686108.png  When struggling rapper Coco (Azealia Banks) en...  1h 46min
# tt0445033.png  A man taking revenge on the killers of his loy...  2h 42min
# tt1167599.png  The story of a young Viking boy who accompanie...  1h 25min
#
#                COLOR    YEAR              DIRECTOR          BUDGET  \
# CODE
# tt4686108.png  Color  (2017)                   RZA         unknown
# tt0445033.png  Color  (2004)  Lawrence Raghavendra  INR150,000,000
# tt1167599.png  Color  (2009)        Michael Herbig    EUR8,000,000
#
#                        CWG RATING  VOTES METASCORE RATING  \
# CODE
# tt4686108.png      unknown    5,3    766               54
# tt0445033.png      unknown    6,4  1.000          unknown
# ...

# %%
filtered_df_with_img.to_csv('filtered_df_with_imgNames.csv')
