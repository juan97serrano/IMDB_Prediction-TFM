# %%
from selenium import webdriver 
import csv   
from selenium.common.exceptions import *
import time
import pandas as pd
import numpy as np

# %%
def film_info(film):
    film_info = []
    csv_row = []
    
    film_info.append(film) #1 CODIGO 
    
    try:
        title = browser.find_element_by_xpath("//span[contains(@id, 'titleYear')]/parent::h1") #2 TITULO
        head, sep, tail = title.text.partition(' (')
        film_info.append(head)
    except NoSuchElementException:
        film_info.append("unknown")
  
    try:
        description = browser.find_element_by_class_name('summary_text') #3 DESCRIPCIÓN
        film_info.append(description.text)
    except NoSuchElementException:
        film_info.append("unknown")
  
    try:
        duration = browser.find_element_by_tag_name('time') #4 DURACIÓN
        film_info.append(duration.text)
    except NoSuchElementException:
        film_info.append("unknown")
        
    try:
        color = browser.find_element_by_xpath("//h4[text()='Color:']/following-sibling::a") #5 COLOR
        film_info.append(color.text)
    except NoSuchElementException:
        film_info.append("unknown")
    
    try:
        year = browser.find_element_by_id('titleYear') #6 AÑO
        film_info.append(year.text)
    except NoSuchElementException:
        film_info.append("unknown")
    
    try:
        director = browser.find_element_by_xpath("//h4[text()='Director:']/following-sibling::a") #7 DIRECTOR
        film_info.append(director.text)
    except NoSuchElementException:
        film_info.append("unknown")  
    
    try:
        budget = browser.find_element_by_xpath("//h4[text()='Budget:']/parent::div") #8 BUDGET
        if "(estimated)" in budget.text:
            head, sep, tail = budget.text.partition(':')
            film_info.append(tail[:-12])
        else:
            head, sep, tail = budget.text.partition(':')
            film_info.append(tail)
    except NoSuchElementException:
        film_info.append("unknown") 
        
    try:    
        cwg = browser.find_element_by_xpath("//h4[text()='Cumulative Worldwide Gross:']/parent::div") #9 CUMULATIVE WORLDWIDE GROSS
        head, sep, tail = cwg.text.partition(': ')
        film_info.append(tail)
    except NoSuchElementException:
        film_info.append("unknown")    
    
    try:
        IMBD_rating = browser.find_element_by_xpath("//span[@itemprop='ratingValue']") #10 RATING
        film_info.append(IMBD_rating.text)
    except NoSuchElementException:
        film_info.append("unknown")    
    
    try:
        votes = browser.find_element_by_xpath("//span[@itemprop='ratingCount']") #11 NUM VOTOS
        film_info.append(votes.text)
    except NoSuchElementException:
        film_info.append("unknown")    
    
    try:
        metascore_rating = browser.find_element_by_xpath("//div[contains(@class, 'metacriticScore')]") #12 METASCORE RATING
        film_info.append(metascore_rating.text)
    except NoSuchElementException:
        film_info.append("unknown")        
    
    try:
        genres = browser.find_element_by_xpath("//h4[text()='Genres:']/parent::div") #13 GENERO
        head, sep, tail = genres.text.partition(': ')
        film_info.append(tail)
    except NoSuchElementException:
        film_info.append("unknown")
        
    try:
        language = browser.find_element_by_xpath("//h4[text()='Language:']/parent::div") #14 LENGUA
        head, sep, tail = language.text.partition(': ')
        film_info.append(tail)
    except NoSuchElementException:
        film_info.append("unknown")    
        
    try:    
        country = browser.find_element_by_xpath("//h4[text()='Country:']/parent::div") #15 COUNTRY
        head, sep, tail = country.text.partition(': ')
        film_info.append(tail)
    except NoSuchElementException:
        film_info.append("unknown")
        
    try:   
        certification = browser.find_element_by_xpath("//h4[text()='Certificate:']/parent::div") #16 EDAD
        head, sep, tail = certification.text.partition(': ')
        film_info.append(tail)
    except NoSuchElementException:
        film_info.append("unknown")
        
    try:   
        keywords = browser.find_element_by_xpath("//h4[text()='Plot Keywords:']/parent::div") #17 PALABRAS CLAVE
        head, sep, tail = keywords.text.partition(': ')
        film_info.append(tail)
    except NoSuchElementException:
        film_info.append("unknown")
        
    try:
        writer = browser.find_element_by_xpath("//h4[text()='Writers:']/parent::div | //h4[text()='Writer:']/parent::div ") #18 ESCRITORES
        head, sep, tail = writer.text.partition(': ')
        film_info.append(tail)
    except NoSuchElementException:
        film_info.append("unknown")
        
    try:   
        opening_weekend = browser.find_element_by_xpath("//h4[text()='Opening Weekend USA:']/parent::div") #19 FIN DE SEMANA DE LANZAMIENTO
        head, sep, tail = opening_weekend.text.partition(': ')
        film_info.append(tail)
    except NoSuchElementException:
        film_info.append("unknown")
    
    csv_row.append(film_info)

    return csv_row

# %%
def header():
    csv_row=[]
    head = ["CODE","TITLE","DESCRIPTION", "DURATION", "COLOR", "YEAR", "DIRECTOR", "BUDGET", "CWG", "RATING", \
            "VOTES", "METASCORE RATING", "GENRES", "LANGUAGE", "COUNTRY", "CONTENT RATING", "KEYWORDS", \
            "WRITERS", "OPENING WEEKEND"]
    csv_row.append(head)
    return csv_row

# %%
#test_films = ['tt0071562', 'tt7286456','tt0187393','tt0000001','tt0000002','tt0000003','tt0000004']
#id_films = test_films
id_films = np.load('lista_final_ids.npy',allow_pickle=True).tolist()
browser = webdriver.Firefox()
row = 0
for film in id_films:
    
    url = 'https://www.imdb.com/title/'+film+'/?ref_=fn_al_tt_1' 
    browser.get(url)
    
    with open('IMBD_data.csv', 'a', encoding="utf-8") as f:                
        
        writer = csv.writer(f,delimiter='\t')
        if row == 0 :
            writer.writerows(header())
        writer.writerows(film_info(film))
    
    row += 1
    if row % 1000 == 0:
        print(row)
# Out:
# [['tt0071562', 'El padrino: Parte II', 'The early life and career of Vito Corleone in 1920s New York City is portrayed, while his son, Michael, expands and tightens his grip on the family crime syndicate.', '3h 22min', 'Color', '(1974)', 'Francis Ford Coppola', '$13,000,000', '$48,035,783', '9,0', '1.054.961', '90', 'Crime | Drama', 'English | Italian | Spanish | Latin | Sicilian', 'USA', '18 | See all certifications »', 'revenge | corrupt politician | bloody body of child | mafia | 1950s | See All (276) »', 'Francis Ford Coppola (screenplay by), Mario Puzo (screenplay by) | 1 more credit »', '$171,417, 10 November 2019']]
# [['tt7286456', 'Joker', 'In Gotham City, mentally troubled comedian Arthur Fleck is disregarded and mistreated by society. He then embarks on a downward spiral of revolution and bloody crime. This path brings him face-to-face with his alter-ego: the Joker.', '2h 2min', 'Color', '(2019)', 'Todd Phillips', '$55,000,000', '$1,071,702,702', '8,6', '650.123', '59', 'Crime | Drama | Thriller', 'English', 'USA | Canada', '18 | See all certifications »', 'mental illness | evil clown | based on comic | nihilism | stand up comedian | See All (470) »', 'Todd Phillips, Scott Silver | 3 more credits »', '$96,202,337, 6 October 2019']]
# [['tt0187393', 'El patriota', 'Peaceful farmer Benjamin Martin is driven to lead the Colonial Militia during the American Revolution when a sadistic British officer murders his son.', '2h 45min', 'Color', '(2000)', 'Roland Emmerich', '$110,000,000', '$215,294,342', '7,2', '243.846', '63', 'Action | Drama | History | War', 'English | French', 'USA | Germany', '13 | See all certifications »', 'american revolution | hero | standoff | father son relationship | george washington character | See All (176) »', 'Robert Rodat', '$22,413,710, 2 July 2000']]
# [['tt0000001', 'Carmencita', 'Performing on what looks like a small wooden stage, wearing a dress with a hoop skirt and white high-heeled pumps, Carmencita does a dance with kicks and twirls, a smile always on her face.', '1min', 'Black and White', '(1894)', 'William K.L. Dickson', 'unknown', 'unknown', '5,6', '1.582', 'unknown', 'Documentary | Short', 'unknown', 'USA', 'See all certifications »', 'dance | music hall | kinetoscope | actress | theatre | See All (19) »', 'unknown', 'unknown']]
# [['tt0000002', 'Le clown et ses chiens', 'Short film of 300 individually painted images.', '5min', 'Color', '(1892)', 'Émile Reynaud', 'unknown', 'unknown', '6,1', '189', 'unknown', 'Animation | Short', 'unknown', 'France', 'unknown', 'dog | clown | See All (2) »', 'unknown', 'unknown']]
# [['tt0000003', 'Pauvre Pierrot', 'One night, Arlequin come to see his lover Colombine. But then Pierrot knocks at the door and Colombine and Arlequin hide. Pierrot starts singing but Arlequin scares him and the poor man goes away.', '4min', 'Color', '(1892)', 'Émile Reynaud', 'unknown', 'unknown', '6,5', '1.244', 'unknown', 'Animation | Comedy | Short | Romance', 'unknown', 'France', 'unknown', 'early animation | See All (1) »', 'unknown', 'unknown']]
# [['tt0000004', 'Un bon bock', 'Add a Plot »', 'unknown', 'Color', '(1892)', 'Émile Reynaud', 'unknown', 'unknown', '6,2', '117', 'unknown', 'Animation | Short', 'unknown', 'France', 'unknown', 'lost film | three word title | early animation | first of its kind | See All (4) »', 'unknown', 'unknown']]

# %%
data =  pd.read_csv('IMBD_data.csv',  sep='\t', engine='python', header= 0)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-160-0aac6751ae8d> in <module>
# ----> 1 data =  pd.read_csv('IMBD_data.csv',  sep='\t', engine='python', header= 0)
#
# ~\Anaconda3\lib\site-packages\pandas\io\parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     683         )
#     684
# --> 685         return _read(filepath_or_buffer, kwds)
#     686
#     687     parser_f.__name__ = name
#
# ~\Anaconda3\lib\site-packages\pandas\io\parsers.py in _read(filepath_or_buffer, kwds)
#     455
#     456     # Create the parser.
# --> 457     parser = TextFileReader(fp_or_buf, **kwds)
#     458
#     459     if chunksize or iterator:
#
# ~\Anaconda3\lib\site-packages\pandas\io\parsers.py in __init__(self, f, engine, **kwds)
#     893             self.options["has_index_names"] = kwds["has_index_names"]
#     894
# --> 895         self._make_engine(self.engine)
#     896
#     897     def close(self):
#
# ~\Anaconda3\lib\site-packages\pandas\io\parsers.py in _make_engine(self, engine)
#    1145                     ' "python-fwf")'.format(engine=engine)
#    1146                 )
# -> 1147             self._engine = klass(self.f, **self.options)
#    1148
#    1149     def _failover_to_python(self):
#
# ~\Anaconda3\lib\site-packages\pandas\io\parsers.py in __init__(self, f, **kwds)
#    2291             encoding=self.encoding,
#    2292             compression=self.compression,
# -> 2293             memory_map=self.memory_map,
#    2294         )
#    2295         self.handles.extend(handles)
#
# ~\Anaconda3\lib\site-packages\pandas\io\common.py in _get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text)
#     400         elif is_text:
#     401             # No explicit encoding
# --> 402             f = open(path_or_buf, mode, errors="replace", newline="")
#     403         else:
#     404             # Binary mode
#
# FileNotFoundError: [Errno 2] No such file or directory: 'IMBD_data.csv'

# %%
data
# Out:
#          CODE                   TITLE  \
# 0   tt0071562    El padrino: Parte II
# 1   tt7286456                   Joker
# 2   tt0187393             El patriota
# 3   tt0000001              Carmencita
# 4   tt0000002  Le clown et ses chiens
# 5   tt0000003          Pauvre Pierrot
# 6   tt0000004             Un bon bock
# 7        CODE                   TITLE
# 8   tt0071562    El padrino: Parte II
# 9   tt7286456                   Joker
# 10  tt0187393             El patriota
# 11  tt0000001              Carmencita
# 12  tt0000002  Le clown et ses chiens
# 13  tt0000003          Pauvre Pierrot
# 14  tt0000004             Un bon bock
# 15       CODE                   TITLE
# 16  tt0071562    El padrino: Parte II
# 17  tt7286456                   Joker
# 18  tt0187393             El patriota
# 19  tt0000001              Carmencita
# 20  tt0000002  Le clown et ses chiens
# 21  tt0000003          Pauvre Pierrot
# 22  tt0000004             Un bon bock
# 23       CODE                   TITLE
# 24  tt0071562    El padrino: Parte II
# 25  tt7286456                   Joker
# 26  tt0187393             El patriota
# 27  tt0000001              Carmencita
# 28  tt0000002  Le clown et ses chiens
# 29  tt0000003          Pauvre Pierrot
# 30  tt0000004             Un bon bock
#
#                                           DESCRIPTION  DURATION  \
# 0   The early life and career of Vito Corleone in ...  3h 22min
# 1   In Gotham City, mentally troubled comedian Art...   2h 2min
# 2   Peaceful farmer Benjamin Martin is driven to l...  2h 45min
# 3   Performing on what looks like a small wooden s...      1min
# 4      Short film of 300 individually painted images.      5min
# 5   One night, Arlequin come to see his lover Colo...      4min
# 6                                       Add a Plot Â»   unknown
# 7                                         DESCRIPTION  DURATION
# 8   The early life and career of Vito Corleone in ...  3h 22min
# 9   In Gotham City, mentally troubled comedian Art...   2h 2min
# 10  Peaceful farmer Benjamin Martin is driven to l...  2h 45min
# 11  Performing on what looks like a small wooden s...      1min
# 12     Short film of 300 individually painted images.      5min
# 13  One night, Arlequin come to see his lover Colo...      4min
# 14                                      Add a Plot Â»   unknown
# 15                                        DESCRIPTION  DURATION
# 16  The early life and career of Vito Corleone in ...  3h 22min
# 17  In Gotham City, mentally troubled comedian Art...   2h 2min
# 18  Peaceful farmer Benjamin Martin is driven to l...  2h 45min
# 19  Performing on what looks like a small wooden s...      1min
# 20     Short film of 300 individually painted images.      5min
# 21  One night, Arlequin come to see his lover Colo...      4min
# 22                                      Add a Plot Â»   unknown
# 23                                        DESCRIPTION  DURATION
# 24  The early life and career of Vito Corleone in ...  3h 22min
# 25  In Gotham City, mentally troubled comedian Art...   2h 2min
# 26  Peaceful farmer Benjamin Martin is driven to l...  2h 45min
# 27  Performing on what looks like a small wooden s...      1min
# 28     Short film of 300 individually painted images.      5min
# 29  One night, Arlequin come to see his lover Colo...      4min
# 30                                      Add a Plot Â»   unknown
#
#               COLOR    YEAR              DIRECTOR        BUDGET  \
# 0             Color  (1974)  Francis Ford Coppola   $13,000,000
# 1             Color  (2019)         Todd Phillips   $55,000,000
# 2             Color  (2000)       Roland Emmerich  $110,000,000
# 3   Black and White  (1894)  William K.L. Dickson       unknown
# 4             Color  (1892)        Ã‰mile Reynaud       unknown
# 5             Color  (1892)        Ã‰mile Reynaud       unknown
# 6             Color  (1892)        Ã‰mile Reynaud       unknown
# 7             COLOR    YEAR              DIRECTOR        BUDGET
# 8             Color  (1974)  Francis Ford Coppola   $13,000,000
# 9             Color  (2019)         Todd Phillips   $55,000,000
# 10            Color  (2000)       Roland Emmerich  $110,000,000
# 11  Black and White  (1894)  William K.L. Dickson       unknown
# 12            Color  (1892)        Ã‰mile Reynaud       unknown
# 13            Color  (1892)        Ã‰mile Reynaud       unknown
# 14            Color  (1892)        Ã‰mile Reynaud       unknown
# 15            COLOR    YEAR              DIRECTOR        BUDGET
# 16            Color  (1974)  Francis Ford Coppola   $13,000,000
# 17            Color  (2019)         Todd Phillips   $55,000,000
# 18            Color  (2000)       Roland Emmerich  $110,000,000
# 19  Black and White  (1894)  William K.L. Dickson       unknown
# 20            Color  (1892)        Ã‰mile Reynaud       unknown
# 21            Color  (1892)        Ã‰mile Reynaud       unknown
# 22            Color  (1892)        Ã‰mile Reynaud       unknown
# 23            COLOR    YEAR              DIRECTOR        BUDGET
# 24            Color  (1974)  Francis Ford Coppola   $13,000,000
# 25            Color  (2019)         Todd Phillips   $55,000,000
# 26            Color  (2000)       Roland Emmerich  $110,000,000
# 27  Black and White  (1894)  William K.L. Dickson       unknown
# 28            Color  (1892)        Ã‰mile Reynaud       unknown
# 29            Color  (1892)        Ã‰mile Reynaud       unknown
# 30            Color  (1892)        Ã‰mile Reynaud       unknown
#
#                CWG  RATING      VOTES  METASCORE RATING  \
# 0      $48,035,783     9,0  1.054.961                90
# 1   $1,071,702,702     8,6    650.123                59
# 2     $215,294,342     7,2    243.846                63
# 3          unknown     5,6      1.582           unknown
# 4          unknown     6,1        189           unknown
# 5          unknown     6,5      1.244           unknown
# 6          unknown     6,2        117           unknown
# 7              CWG  RATING      VOTES  METASCORE RATING
# 8      $48,035,783     9,0  1.054.961                90
# 9   $1,071,702,702     8,6    650.123                59
# 10    $215,294,342     7,2    243.846                63
# 11         unknown     5,6      1.582           unknown
# 12         unknown     6,1        189           unknown
# 13         unknown     6,5      1.244           unknown
# 14         unknown     6,2        117           unknown
# 15             CWG  RATING      VOTES  METASCORE RATING
# 16     $48,035,783     9,0  1.054.961                90
# 17  $1,071,702,702     8,6    650.123                59
# 18    $215,294,342     7,2    243.846                63
# 19         unknown     5,6      1.582           unknown
# 20         unknown     6,1        189           unknown
# 21         unknown     6,5      1.244           unknown
# 22         unknown     6,2        117           unknown
# 23             CWG  RATING      VOTES  METASCORE RATING
# 24     $48,035,783     9,0  1.054.961                90
# 25  $1,071,702,702     8,6    650.123                59
# 26    $215,294,342     7,2    243.846                63
# 27         unknown     5,6      1.582           unknown
# 28         unknown     6,1        189           unknown
# 29         unknown     6,5      1.244           unknown
# 30         unknown     6,2        117           unknown
#
#                                   GENRES  \
# 0                          Crime | Drama
# 1               Crime | Drama | Thriller
# 2         Action | Drama | History | War
# 3                    Documentary | Short
# 4                      Animation | Short
# 5   Animation | Comedy | Short | Romance
# 6                      Animation | Short
# 7                                 GENRES
# 8                          Crime | Drama
# 9               Crime | Drama | Thriller
# 10        Action | Drama | History | War
# 11                   Documentary | Short
# 12                     Animation | Short
# 13  Animation | Comedy | Short | Romance
# 14                     Animation | Short
# 15                                GENRES
# 16                         Crime | Drama
# 17              Crime | Drama | Thriller
# 18        Action | Drama | History | War
# 19                   Documentary | Short
# 20                     Animation | Short
# 21  Animation | Comedy | Short | Romance
# 22                     Animation | Short
# 23                                GENRES
# 24                         Crime | Drama
# 25              Crime | Drama | Thriller
# 26        Action | Drama | History | War
# 27                   Documentary | Short
# 28                     Animation | Short
# 29  Animation | Comedy | Short | Romance
# 30                     Animation | Short
#
#                                           LANGUAGE        COUNTRY  \
# 0   English | Italian | Spanish | Latin | Sicilian            USA
# 1                                          English   USA | Canada
# 2                                 English | French  USA | Germany
# 3                                          unknown            USA
# 4                                          unknown         France
# 5                                          unknown         France
# 6                                          unknown         France
# 7                                         LANGUAGE        COUNTRY
# 8   English | Italian | Spanish | Latin | Sicilian            USA
# 9                                          English   USA | Canada
# 10                                English | French  USA | Germany
# 11                                         unknown            USA
# 12                                         unknown         France
# 13                                         unknown         France
# 14                                         unknown         France
# 15                                        LANGUAGE        COUNTRY
# 16  English | Italian | Spanish | Latin | Sicilian            USA
# 17                                         English   USA | Canada
# 18                                English | French  USA | Germany
# 19                                         unknown            USA
# 20                                         unknown         France
# 21                                         unknown         France
# 22                                         unknown         France
# 23                                        LANGUAGE        COUNTRY
# 24  English | Italian | Spanish | Latin | Sicilian            USA
# 25                                         English   USA | Canada
# 26                                English | French  USA | Germany
# 27                                         unknown            USA
# 28                                         unknown         France
# 29                                         unknown         France
# 30                                         unknown         France
#
#                     CONTENT RATING  \
# 0   18 | See all certifications Â»
# 1   18 | See all certifications Â»
# 2   13 | See all certifications Â»
# 3        See all certifications Â»
# 4                          unknown
# 5                          unknown
# 6                          unknown
# 7                   CONTENT RATING
# 8   18 | See all certifications Â»
# 9   18 | See all certifications Â»
# 10  13 | See all certifications Â»
# 11       See all certifications Â»
# 12                         unknown
# 13                         unknown
# 14                         unknown
# 15                  CONTENT RATING
# 16  18 | See all certifications Â»
# 17  18 | See all certifications Â»
# 18  13 | See all certifications Â»
# 19       See all certifications Â»
# 20                         unknown
# 21                         unknown
# 22                         unknown
# 23                  CONTENT RATING
# 24  18 | See all certifications Â»
# 25  18 | See all certifications Â»
# 26  13 | See all certifications Â»
# 27       See all certifications Â»
# 28                         unknown
# 29                         unknown
# 30                         unknown
#
#                                              KEYWORDS  \
# 0   revenge | corrupt politician | bloody body of ...
# 1   mental illness | evil clown | based on comic |...
# 2   american revolution | hero | standoff | father...
# 3   dance | music hall | kinetoscope | actress | t...
# 4                        dog | clown | See All (2) Â»
# 5                    early animation | See All (1) Â»
# 6   lost film | three word title | early animation...
# 7                                            KEYWORDS
# 8   revenge | corrupt politician | bloody body of ...
# 9   mental illness | evil clown | based on comic |...
# 10  american revolution | hero | standoff | father...
# 11  dance | music hall | kinetoscope | actress | t...
# 12                       dog | clown | See All (2) Â»
# 13                   early animation | See All (1) Â»
# 14  lost film | three word title | early animation...
# 15                                           KEYWORDS
# 16  revenge | corrupt politician | bloody body of ...
# 17  mental illness | evil clown | based on comic |...
# 18  american revolution | hero | standoff | father...
# 19  dance | music hall | kinetoscope | actress | t...
# 20                       dog | clown | See All (2) Â»
# 21                   early animation | See All (1) Â»
# 22  lost film | three word title | early animation...
# 23                                           KEYWORDS
# 24  revenge | corrupt politician | bloody body of ...
# 25  mental illness | evil clown | based on comic |...
# 26  american revolution | hero | standoff | father...
# 27  dance | music hall | kinetoscope | actress | t...
# 28                       dog | clown | See All (2) Â»
# 29                   early animation | See All (1) Â»
# 30  lost film | three word title | early animation...
#
#                                               WRITERS  \
# 0   Francis Ford Coppola (screenplay by), Mario Pu...
# 1     Todd Phillips, Scott Silver | 3 more credits Â»
# 2                                        Robert Rodat
# 3                                             unknown
# 4                                             unknown
# 5                                             unknown
# 6                                             unknown
# 7                                             WRITERS
# 8   Francis Ford Coppola (screenplay by), Mario Pu...
# 9     Todd Phillips, Scott Silver | 3 more credits Â»
# 10                                       Robert Rodat
# 11                                            unknown
# 12                                            unknown
# 13                                            unknown
# 14                                            unknown
# 15                                            WRITERS
# 16  Francis Ford Coppola (screenplay by), Mario Pu...
# 17    Todd Phillips, Scott Silver | 3 more credits Â»
# 18                                       Robert Rodat
# 19                                            unknown
# 20                                            unknown
# 21                                            unknown
# 22                                            unknown
# 23                                            WRITERS
# 24  Francis Ford Coppola (screenplay by), Mario Pu...
# 25    Todd Phillips, Scott Silver | 3 more credits Â»
# 26                                       Robert Rodat
# 27                                            unknown
# 28                                            unknown
# 29                                            unknown
# 30                                            unknown
#
#                             RELEASE DATE
# 0    13 October 1975 (Spain) See more Â»
# 1     4 October 2019 (Spain) See more Â»
# 2       11 July 2000 (Spain) See more Â»
# 3        10 March 1894 (USA) See more Â»
# 4   28 October 1892 (France) See more Â»
# 5   28 October 1892 (France) See more Â»
# 6   28 October 1892 (France) See more Â»
# 7                           RELEASE DATE
# 8             $171,417, 10 November 2019
# 9            $96,202,337, 6 October 2019
# 10              $22,413,710, 2 July 2000
# 11                               unknown
# 12                               unknown
# 13                               unknown
# 14                               unknown
# 15                          RELEASE DATE
# 16            $171,417, 10 November 2019
# 17           $96,202,337, 6 October 2019
# 18              $22,413,710, 2 July 2000
# 19                               unknown
# 20                               unknown
# 21                               unknown
# 22                               unknown
# 23                       OPENING WEEKEND
# 24            $171,417, 10 November 2019
# 25           $96,202,337, 6 October 2019
# 26              $22,413,710, 2 July 2000
# 27                               unknown
# 28                               unknown
# 29                               unknown
# 30                               unknown
