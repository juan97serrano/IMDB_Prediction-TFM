# %%
from pandas import DataFrame
from selenium import webdriver 


import pandas as pd

# %%
df = pd.read_csv("title.basics.tsv", sep="\t",nrows=1000)
df_filter = df[df['titleType'] == 'movie']
df_filter_reset_index = df_filter.reset_index()

# %%
df_filter_reset_index
# Out:
#     index     tconst titleType  \
# 0       8  tt0000009     movie
# 1     145  tt0000147     movie
# 2     332  tt0000335     movie
# 3     499  tt0000502     movie
# 4     571  tt0000574     movie
# 5     611  tt0000615     movie
# 6     626  tt0000630     movie
# 7     669  tt0000675     movie
# 8     670  tt0000676     movie
# 9     673  tt0000679     movie
# 10    730  tt0000739     movie
# 11    784  tt0000793     movie
# 12    803  tt0000812     movie
# 13    805  tt0000814     movie
# 14    829  tt0000838     movie
# 15    833  tt0000842     movie
# 16    837  tt0000846     movie
# 17    841  tt0000850     movie
# 18    850  tt0000859     movie
# 19    853  tt0000862     movie
# 20    858  tt0000867     movie
# 21    859  tt0000868     movie
# 22    860  tt0000869     movie
# 23    870  tt0000879     movie
# 24    877  tt0000886     movie
# 25    931  tt0000941     movie
# 26    937  tt0000947     movie
# 27    949  tt0000959     movie
# 28    973  tt0000984     movie
# 29    981  tt0000992     movie
# 30    996  tt0001007     movie
# 31    999  tt0001010     movie
#
#                                          primaryTitle  \
# 0                                          Miss Jerry
# 1                       The Corbett-Fitzsimmons Fight
# 2                               Soldiers of the Cross
# 3                                            Bohemios
# 4                         The Story of the Kelly Gang
# 5                                  Robbery Under Arms
# 6                                              Hamlet
# 7                                         Don Quijote
# 8                     Don Álvaro o la fuerza del sino
# 9                      The Fairylogue and Radio-Plays
# 10                          El pastorcito de Torrente
# 11                                      Andreas Hofer
# 12                                  El blocao Velarde
# 13                             La bocana de Mar Chica
# 14                                 A Cultura do Cacau
# 15                              De Garraf a Barcelona
# 16                               Un día en Xochimilco
# 17                                   Los dos hermanos
# 18    Fabricación del corcho en Sant Feliu de Guixols
# 19                                         Faldgruben
# 20                                    Fiesta de toros
# 21                   Fiestas de Santa Lucía - Belenes
# 22                              Fiestas en La Garriga
# 23              Gira política de Madero y Pino Suárez
# 24                          Hamlet, Prince of Denmark
# 25                                     Locura de amor
# 26                                       Lægens offer
# 27                                Melilla y el Gurugu
# 28                                Niños en la alameda
# 29                                       De onde Veje
# 30                       La primera y segunda casetas
# 31  Protección de un convoy de víveres en el puent...
#
#                                         originalTitle  isAdult  startYear  \
# 0                                          Miss Jerry        0       1894
# 1                       The Corbett-Fitzsimmons Fight        0       1897
# 2                               Soldiers of the Cross        0       1900
# 3                                            Bohemios        0       1905
# 4                         The Story of the Kelly Gang        0       1906
# 5                                  Robbery Under Arms        0       1907
# 6                                              Amleto        0       1908
# 7                                         Don Quijote        0       1908
# 8                     Don Álvaro o la fuerza del sino        0       1908
# 9                      The Fairylogue and Radio-Plays        0       1908
# 10                          El pastorcito de Torrente        0       1908
# 11                                      Andreas Hofer        0       1909
# 12                                  El blocao Velarde        0       1909
# 13                             La bocana de Mar Chica        0       1909
# 14                                 A Cultura do Cacau        0       1909
# 15                              De Garraf a Barcelona        0       1909
# 16                               Un día en Xochimilco        0       1909
# 17                                   Los dos hermanos        0       1909
# 18    Fabricación del corcho en Sant Feliu de Guixols        0       1909
# 19                                         Faldgruben        0       1909
# 20                                    Fiesta de toros        0       1909
# 21                   Fiestas de Santa Lucía - Belenes        0       1909
# 22                              Fiestas en La Garriga        0       1909
# 23              Gira política de Madero y Pino Suárez        0       1909
# 24                                             Hamlet        0       1910
# 25                                     Locura de amor        0       1909
# 26                                       Lægens offer        0       1909
# 27                                Melilla y el Gurugu        0       1909
# 28                                Niños en la alameda        0       1909
# 29                                       De onde Veje        0       1909
# 30                       La primera y segunda casetas        0       1909
# 31  Protección de un convoy de víveres en el puent...        0       1909
#
#    endYear runtimeMinutes                  genres
# 0       \N             45                 Romance
# 1       \N             20  Documentary,News,Sport
# 2       \N             \N         Biography,Drama
# 3       \N            100                      \N
# 4       \N             70   Biography,Crime,Drama
# 5       \N             \N                   Drama
# 6       \N             \N                   Drama
# 7       \N             \N                   Drama
# 8       \N             \N                   Drama
# 9       \N            120       Adventure,Fantasy
# 10      \N             \N                   Drama
# 11      \N             \N                   Drama
# 12      \N             \N                      \N
# 13      \N             \N                      \N
# 14      \N             \N                      \N
# 15      \N             \N                      \N
# 16      \N             \N                      \N
# 17      \N             \N                      \N
# 18      \N             \N                      \N
# 19      \N             \N                      \N
# 20      \N             \N                      \N
# 21      \N             \N                      \N
# 22      \N             \N                      \N
# 23      \N             \N                      \N
# 24      \N             \N                   Drama
# 25      \N             \N                   Drama
# 26      \N             \N                      \N
# 27      \N             \N                      \N
# 28      \N             \N                      \N
# 29      \N             \N                      \N
# 30      \N             \N                      \N
# 31      \N             \N                      \N

# %%
ids_film = df_filter_reset_index['tconst'].tolist()
len(ids_film)
# Out:
# 32

# %%
driver = webdriver.Chrome(executable_path='local/chromedriver')
correct_films = 0

#test_list = ['tt7286456',ids_film[538827],'tt0187393']

for num,film in enumerate(ids_film):
    
    print("Imagen número:",num,", ID:", film)

    url = 'https://www.imdb.com/title/'+film+'/?ref_=fn_al_tt_1' 
    #url = 'https://pro.imdb.com/title/'+film
    driver.get(url)
    
    # Busca los elementos que tienen en el contenido un determinado texto, budget y cumulative...
    #description = driver.find_element_by_class_name('title_wrapper')
    img = driver.find_element_by_class_name('poster').find_element_by_class_name()
    src = img.get_attribute('src')
    tag_name = "film"
    os.system("wget %s --no-check-certificate -O %s.png"%(src,tag_name))
    print(img.text)
driver.close()
# Out:
# Imagen número: 0 , ID: tt0000009
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-d7993acb6042> in <module>
#      17     src = img.get_attribute('src')
#      18     tag_name = "film"
# ---> 19     os.system("wget %s --no-check-certificate -O %s.png"%(src,tag_name))
#      20     print(img.text)
#      21 driver.close()
#
# NameError: name 'os' is not defined

# %%
df = DataFrame.from_csv("title.ratings.tsv", sep="\t")
# Out:
# //anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: FutureWarning: from_csv is deprecated. Please use read_csv(...) instead. Note that some of the default arguments are different, so please refer to the documentation for from_csv when changing your function calls
#   """Entry point for launching an IPython kernel.

# %%
df
# Out:
#            averageRating  numVotes
# tconst
# tt0000001            5.6      1572
# tt0000002            6.1       189
# tt0000003            6.5      1236
# tt0000004            6.2       116
# tt0000005            6.1      1973
# tt0000006            5.2       107
# tt0000007            5.4       624
# tt0000008            5.4      1696
# tt0000009            5.4        86
# tt0000010            6.9      5630
# tt0000011            5.2       242
# tt0000012            7.4      9556
# tt0000013            5.7      1470
# tt0000014            7.1      4181
# tt0000015            6.1       756
# tt0000016            5.9      1110
# tt0000017            4.6       222
# tt0000018            5.4       456
# tt0000019            5.5        17
# tt0000020            5.0       253
# tt0000022            5.1       821
# tt0000023            5.6      1048
# tt0000024            5.0        32
# tt0000025            4.4        25
# tt0000026            5.7      1245
# tt0000027            5.5       866
# tt0000028            5.1       791
# tt0000029            5.9      2677
# tt0000030            5.3       654
# tt0000031            5.5       770
# ...                  ...       ...
# tt9915754            8.6         5
# tt9915780            8.4         8
# tt9915790            7.1         8
# tt9915820            8.1        22
# tt9915822            8.9         7
# tt9915824            7.9        21
# tt9915832            8.4        22
# tt9915864            7.5        17
# tt9915898            9.1       111
# tt9915906            7.7        69
# tt9915910            9.1        92
# tt9915912            7.3        64
# tt9915928            7.6        37
# tt9916114            8.7        20
# tt9916160            6.6        33
# tt9916192            7.4         9
# tt9916200            8.5       137
# tt9916204            8.2       163
# tt9916206            2.5        11
# tt9916316            8.4         5
# tt9916348            8.9        14
# tt9916380            9.2       100
# tt9916420            6.4         8
# tt9916428            3.4        10
# tt9916544            7.3        11
# tt9916576            6.0         8
# tt9916578            8.8        14
# tt9916720            5.3        44
# tt9916766            6.7        11
# tt9916778            6.9        16
#
# [1013006 rows x 2 columns]
