# %% [markdown]
# ## LIBRERÍAS

# %%
import numpy as np
import pandas as pd
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split # Import train_test_split function
from sklearn import metrics 
import matplotlib.pyplot as plt
from sklearn.metrics import plot_confusion_matrix
from sklearn.metrics import classification_report

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %% [markdown]
# ## IMPORTAMOS LOS DATOS

# %%
train_data = pd.read_csv("/content/drive/My Drive/TFM/data/code_train_df.csv",header=0, decimal=',')
test_data = pd.read_csv("/content/drive/My Drive/TFM/data/code_test_df.csv",header=0, decimal=',')

# %%
train_data.head(3)
# Out:
#    Unnamed: 0  COLOR  DIRECTOR  GENRES_0  ...     CODE  DURATION  YEAR  RATING_CAT
# 0           0      0      2894         8  ...    36310        87  1943           1
# 1           1      1      2894         0  ...  5988966        99  2017           0
# 2           2      1      5855        13  ...   100904       101  1990           0
#
# [3 rows x 17 columns]

# %%
FEATURES = ['DURATION','COLOR','YEAR','DIRECTOR','COUNTRY_0','GENRES_0','GENRES_1','GENRES_2','LANGUAGE_0','KEYWORDS_0','KEYWORDS_1','KEYWORDS_2','WRITERS_0','CONTENT_RATING']



x_train = train_data[FEATURES]
y_train = train_data.RATING_CAT

# %%
X_train, X_test, y_train, y_test = train_test_split(x_train, y_train, test_size=0.3, random_state=1) # 70% training and 30% test

# %% [markdown]
# ## RANDOM FOREST

# %% [markdown]
# HIPERPARAMETROS

# %%
for i in range (0, 15):
  FEATURES_2 = FEATURES[:i]+FEATURES[i+1:]
  x_train = train_data[FEATURES_2]
  y_train = train_data.RATING_CAT
  X_train, X_test, y_train, y_test = train_test_split(x_train, y_train, test_size=0.3, random_state=1) # 70% training and 30% test
  clf = RandomForestClassifier(n_estimators=n_estimators,criterion=criterion)

  # Train Decision Tree Classifer
  clf = clf.fit(X_train,y_train)

  #Predict the response for test dataset
  y_pred = clf.predict(X_test)
  print('FEATURES:',FEATURES_2)
  print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
# Out:
# FEATURES: ['COLOR', 'YEAR', 'DIRECTOR', 'COUNTRY_0', 'GENRES_0', 'GENRES_1', 'GENRES_2', 'LANGUAGE_0', 'KEYWORDS_0', 'KEYWORDS_1', 'KEYWORDS_2', 'WRITERS_0', 'CONTENT_RATING']
# Accuracy: 0.5545405069196081
# FEATURES: ['DURATION', 'YEAR', 'DIRECTOR', 'COUNTRY_0', 'GENRES_0', 'GENRES_1', 'GENRES_2', 'LANGUAGE_0', 'KEYWORDS_0', 'KEYWORDS_1', 'KEYWORDS_2', 'WRITERS_0', 'CONTENT_RATING']
# Accuracy: 0.5770486705022547
# FEATURES: ['DURATION', 'COLOR', 'DIRECTOR', 'COUNTRY_0', 'GENRES_0', 'GENRES_1', 'GENRES_2', 'LANGUAGE_0', 'KEYWORDS_0', 'KEYWORDS_1', 'KEYWORDS_2', 'WRITERS_0', 'CONTENT_RATING']
# Accuracy: 0.5629373347846369
# FEATURES: ['DURATION', 'COLOR', 'YEAR', 'COUNTRY_0', 'GENRES_0', 'GENRES_1', 'GENRES_2', 'LANGUAGE_0', 'KEYWORDS_0', 'KEYWORDS_1', 'KEYWORDS_2', 'WRITERS_0', 'CONTENT_RATING']
# Accuracy: 0.576037941222205
# ...

# %%
# sin KEYWORDS_0
FEATURES = ['DURATION', 'COLOR', 'YEAR', 'DIRECTOR', 'COUNTRY_0', 'GENRES_0', 'GENRES_1', 'GENRES_2', 'LANGUAGE_0', 'KEYWORDS_1', 'KEYWORDS_2', 'WRITERS_0', 'CONTENT_RATING']

# %%
for i in range (0, 14):
  FEATURES_2 = FEATURES[:i]+FEATURES[i+1:]
  x_train = train_data[FEATURES_2]
  y_train = train_data.RATING_CAT
  X_train, X_test, y_train, y_test = train_test_split(x_train, y_train, test_size=0.3, random_state=1) # 70% training and 30% test
  clf = RandomForestClassifier(n_estimators=n_estimators,criterion=criterion)

  # Train Decision Tree Classifer
  clf = clf.fit(X_train,y_train)

  #Predict the response for test dataset
  y_pred = clf.predict(X_test)
  print('FEATURES:',FEATURES_2)
  print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
# Out:
# FEATURES: ['COLOR', 'YEAR', 'DIRECTOR', 'COUNTRY_0', 'GENRES_0', 'GENRES_1', 'GENRES_2', 'LANGUAGE_0', 'KEYWORDS_1', 'KEYWORDS_2', 'WRITERS_0', 'CONTENT_RATING']
# Accuracy: 0.5556678588088945
# FEATURES: ['DURATION', 'YEAR', 'DIRECTOR', 'COUNTRY_0', 'GENRES_0', 'GENRES_1', 'GENRES_2', 'LANGUAGE_0', 'KEYWORDS_1', 'KEYWORDS_2', 'WRITERS_0', 'CONTENT_RATING']
# Accuracy: 0.5766210542683875
# FEATURES: ['DURATION', 'COLOR', 'DIRECTOR', 'COUNTRY_0', 'GENRES_0', 'GENRES_1', 'GENRES_2', 'LANGUAGE_0', 'KEYWORDS_1', 'KEYWORDS_2', 'WRITERS_0', 'CONTENT_RATING']
# Accuracy: 0.5634038252215829
# FEATURES: ['DURATION', 'COLOR', 'YEAR', 'COUNTRY_0', 'GENRES_0', 'GENRES_1', 'GENRES_2', 'LANGUAGE_0', 'KEYWORDS_1', 'KEYWORDS_2', 'WRITERS_0', 'CONTENT_RATING']
# Accuracy: 0.5773596641268854
# FEATURES: ['DURATION', 'COLOR', 'YEAR', 'DIRECTOR', 'GENRES_0', 'GENRES_1', 'GENRES_2', 'LANGUAGE_0', 'KEYWORDS_1', 'KEYWORDS_2', 'WRITERS_0', 'CONTENT_RATING']
# Accuracy: 0.5724226403358731
# ...

# %%
# sin GENRES_2
FEATURES = ['DURATION', 'COLOR', 'YEAR', 'DIRECTOR', 'COUNTRY_0', 'GENRES_0', 'GENRES_1', 'LANGUAGE_0', 'KEYWORDS_1', 'KEYWORDS_2', 'WRITERS_0', 'CONTENT_RATING']

# %%
for i in range (0, 14):
  FEATURES_2 = FEATURES[:i]+FEATURES[i+1:]
  x_train = train_data[FEATURES_2]
  y_train = train_data.RATING_CAT
  X_train, X_test, y_train, y_test = train_test_split(x_train, y_train, test_size=0.3, random_state=1) # 70% training and 30% test
  clf = RandomForestClassifier(n_estimators=n_estimators,criterion=criterion)

  # Train Decision Tree Classifer
  clf = clf.fit(X_train,y_train)

  #Predict the response for test dataset
  y_pred = clf.predict(X_test)
  print('FEATURES:',FEATURES_2)
  print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
# Out:
# FEATURES: ['COLOR', 'YEAR', 'DIRECTOR', 'COUNTRY_0', 'GENRES_0', 'GENRES_1', 'LANGUAGE_0', 'KEYWORDS_1', 'KEYWORDS_2', 'WRITERS_0', 'CONTENT_RATING']
# Accuracy: 0.5511584512517493
# FEATURES: ['DURATION', 'YEAR', 'DIRECTOR', 'COUNTRY_0', 'GENRES_0', 'GENRES_1', 'LANGUAGE_0', 'KEYWORDS_1', 'KEYWORDS_2', 'WRITERS_0', 'CONTENT_RATING']
# Accuracy: 0.5744829730990515
# FEATURES: ['DURATION', 'COLOR', 'DIRECTOR', 'COUNTRY_0', 'GENRES_0', 'GENRES_1', 'LANGUAGE_0', 'KEYWORDS_1', 'KEYWORDS_2', 'WRITERS_0', 'CONTENT_RATING']
# Accuracy: 0.5646089255170269
# FEATURES: ['DURATION', 'COLOR', 'YEAR', 'COUNTRY_0', 'GENRES_0', 'GENRES_1', 'LANGUAGE_0', 'KEYWORDS_1', 'KEYWORDS_2', 'WRITERS_0', 'CONTENT_RATING']
# Accuracy: 0.5789146322500389
# FEATURES: ['DURATION', 'COLOR', 'YEAR', 'DIRECTOR', 'GENRES_0', 'GENRES_1', 'LANGUAGE_0', 'KEYWORDS_1', 'KEYWORDS_2', 'WRITERS_0', 'CONTENT_RATING']
# Accuracy: 0.5701290623542218
# ...

# %%
# Sin DIRECTOR
FEATURES = ['DURATION', 'COLOR', 'YEAR', 'COUNTRY_0', 'GENRES_0', 'GENRES_1', 'LANGUAGE_0', 'KEYWORDS_1', 'KEYWORDS_2', 'WRITERS_0', 'CONTENT_RATING']

# %%
for i in range (0, 14):
  FEATURES_2 = FEATURES[:i]+FEATURES[i+1:]
  x_train = train_data[FEATURES_2]
  y_train = train_data.RATING_CAT
  X_train, X_test, y_train, y_test = train_test_split(x_train, y_train, test_size=0.3, random_state=1) # 70% training and 30% test
  clf = RandomForestClassifier(n_estimators=n_estimators,criterion=criterion)

  # Train Decision Tree Classifer
  clf = clf.fit(X_train,y_train)

  #Predict the response for test dataset
  y_pred = clf.predict(X_test)
  print('FEATURES:',FEATURES_2)
  print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
# Out:
# FEATURES: ['COLOR', 'YEAR', 'COUNTRY_0', 'GENRES_0', 'GENRES_1', 'LANGUAGE_0', 'KEYWORDS_1', 'KEYWORDS_2', 'WRITERS_0', 'CONTENT_RATING']
# Accuracy: 0.5459493080391852
# FEATURES: ['DURATION', 'YEAR', 'COUNTRY_0', 'GENRES_0', 'GENRES_1', 'LANGUAGE_0', 'KEYWORDS_1', 'KEYWORDS_2', 'WRITERS_0', 'CONTENT_RATING']
# Accuracy: 0.5726170113512673
# FEATURES: ['DURATION', 'COLOR', 'COUNTRY_0', 'GENRES_0', 'GENRES_1', 'LANGUAGE_0', 'KEYWORDS_1', 'KEYWORDS_2', 'WRITERS_0', 'CONTENT_RATING']
# Accuracy: 0.5561343492458405
# FEATURES: ['DURATION', 'COLOR', 'YEAR', 'GENRES_0', 'GENRES_1', 'LANGUAGE_0', 'KEYWORDS_1', 'KEYWORDS_2', 'WRITERS_0', 'CONTENT_RATING']
# Accuracy: 0.5703234333696159
# FEATURES: ['DURATION', 'COLOR', 'YEAR', 'COUNTRY_0', 'GENRES_1', 'LANGUAGE_0', 'KEYWORDS_1', 'KEYWORDS_2', 'WRITERS_0', 'CONTENT_RATING']
# Accuracy: 0.5578059399782305
# ...

# %%
# sin color
FEATURES = ['DURATION', 'YEAR', 'COUNTRY_0', 'GENRES_0', 'GENRES_1', 'LANGUAGE_0', 'KEYWORDS_1', 'KEYWORDS_2', 'WRITERS_0', 'CONTENT_RATING']

# %%
for i in range (0, 14):
  FEATURES_2 = FEATURES[:i]+FEATURES[i+1:]
  x_train = train_data[FEATURES_2]
  y_train = train_data.RATING_CAT
  X_train, X_test, y_train, y_test = train_test_split(x_train, y_train, test_size=0.3, random_state=1) # 70% training and 30% test
  clf = RandomForestClassifier(n_estimators=n_estimators,criterion=criterion)

  # Train Decision Tree Classifer
  clf = clf.fit(X_train,y_train)

  #Predict the response for test dataset
  y_pred = clf.predict(X_test)
  print('FEATURES:',FEATURES_2)
  print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
# Out:
# FEATURES: ['YEAR', 'COUNTRY_0', 'GENRES_0', 'GENRES_1', 'LANGUAGE_0', 'KEYWORDS_1', 'KEYWORDS_2', 'WRITERS_0', 'CONTENT_RATING']
# Accuracy: 0.5445887109314259
# FEATURES: ['DURATION', 'COUNTRY_0', 'GENRES_0', 'GENRES_1', 'LANGUAGE_0', 'KEYWORDS_1', 'KEYWORDS_2', 'WRITERS_0', 'CONTENT_RATING']
# Accuracy: 0.542178510340538
# FEATURES: ['DURATION', 'YEAR', 'GENRES_0', 'GENRES_1', 'LANGUAGE_0', 'KEYWORDS_1', 'KEYWORDS_2', 'WRITERS_0', 'CONTENT_RATING']
# Accuracy: 0.5666692582802052
# FEATURES: ['DURATION', 'YEAR', 'COUNTRY_0', 'GENRES_1', 'LANGUAGE_0', 'KEYWORDS_1', 'KEYWORDS_2', 'WRITERS_0', 'CONTENT_RATING']
# Accuracy: 0.5521303063287203
# FEATURES: ['DURATION', 'YEAR', 'COUNTRY_0', 'GENRES_0', 'LANGUAGE_0', 'KEYWORDS_1', 'KEYWORDS_2', 'WRITERS_0', 'CONTENT_RATING']
# Accuracy: 0.5662805162494169
# FEATURES: ['DURATION', 'YEAR', 'COUNTRY_0', 'GENRES_0', 'GENRES_1', 'KEYWORDS_1', 'KEYWORDS_2', 'WRITERS_0', 'CONTENT_RATING']
# Accuracy: 0.5644145545016327
# ...

# %%
n_estimators=100
criterion = 'gini'

# %%
clf = RandomForestClassifier(n_estimators=n_estimators,criterion=criterion)

# Train Decision Tree Classifer
clf = clf.fit(X_train,y_train)

#Predict the response for test dataset
y_pred = clf.predict(X_test)

# %%
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.5793033742808272

# %%
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.60      0.36      0.45      4841
#            1       0.54      0.67      0.60     11234
#            2       0.63      0.59      0.61      9649
#
#     accuracy                           0.58     25724
#    macro avg       0.59      0.54      0.55     25724
# weighted avg       0.59      0.58      0.57     25724

# %% [markdown]
# ## MATRIZ DE CONFUSIÓN

# %%
print(__doc__)

# Plot non-normalized confusion matrix
titles_options = [("Confusion matrix, without normalization", None),
                  ("Normalized confusion matrix", 'true')]
for title, normalize in titles_options:
    disp = plot_confusion_matrix(clf, X_test, y_test,
                                 display_labels=['0','1','2'],
                                 cmap=plt.cm.Blues,
                                 normalize=normalize)
    disp.ax_.set_title(title)

    print(title)
    print(disp.confusion_matrix)

plt.show()
# Out:
# Automatically created module for IPython interactive environment
# Confusion matrix, without normalization
# [[1741 2552  548]
#  [ 985 7388 2861]
#  [ 285 3685 5679]]
# Normalized confusion matrix
# [[0.35963644 0.52716381 0.11319975]
#  [0.08768026 0.65764643 0.25467331]
#  [0.02953674 0.38190486 0.5885584 ]]

# %% [markdown]
# ## PARA PINTAR EL ÁRBOL

# %%
from sklearn.tree import export_graphviz
from sklearn.externals.six import StringIO  
from IPython.display import Image  
import pydotplus

dot_data = StringIO()
export_graphviz(clf, out_file=dot_data,  
                filled=True, rounded=True,
                special_characters=True,feature_names = FEATURES,class_names=['0','1','2'])
graph = pydotplus.graph_from_dot_data(dot_data.getvalue())  
graph.write_png('diabetes.png')
Image(graph.create_png())
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/externals/six.py:31: FutureWarning: The module is deprecated in version 0.21 and will be removed in version 0.23 since we've dropped support for Python 2.7. Please rely on the official version of six (https://pypi.org/project/six/).
#   "(https://pypi.org/project/six/).", FutureWarning)
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-13-9285ce64361d> in <module>()
#       7 export_graphviz(clf, out_file=dot_data,
#       8                 filled=True, rounded=True,
# ----> 9                 special_characters=True,feature_names = FEATURES,class_names=['0','1','2'])
#      10 graph = pydotplus.graph_from_dot_data(dot_data.getvalue())
#      11 graph.write_png('diabetes.png')
#
# ...
